# %% [markdown]
# ## Technical Set-ups

# %% [markdown]
# ### Command in Terminal
# - conda create -n geeineq python=3.11
# - conda activate geeineq
# - conda install -c conda-forge mamba
# - mamba install -c conda-forge pygis
#
# #### patchly change the name of data files
# `for file in 市*.geojson; do
#   mv "$file" "${file/市/city-level}"
# done`

# %% [markdown]
# ### Import Packages

# %%
import ee
import geemap
import os
import geopandas as gpd
import pandas as pd
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
geemap.ee_initialize()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ### Data Preparation

# %% [markdown]
# #### Step 1: Reading GEOJson Files

# %%
# Path to the directory containing my GEOJson files
data_directory = "./data"

# Dictionary to hold my data, with years as keys
data_by_year = {}

for file_name in os.listdir(data_directory):
    if file_name.endswith('.geojson'):
        # Extract the year from the file name 
        # (assuming the format "city-levelYEAR.geojson")
        # This slices the last 12 characters from the filename, 
        # then takes the first 4 as the year
        year = int(file_name[-12:-8])
        file_path = os.path.join(data_directory, file_name)
        print(f"Processing file: {file_path}")
        data_by_year[year] = gpd.read_file(file_path)
        print(f"Data loaded for year {year}")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Processing file: ./data/city-level1996.geojson
# Data loaded for year 1996
# Processing file: ./data/city-level2003.geojson
# Data loaded for year 2003
# Processing file: ./data/city-level2013.geojson
# Data loaded for year 2013
# Processing file: ./data/city-level1997.geojson
# Data loaded for year 1997
# Processing file: ./data/city-level2012.geojson
# Data loaded for year 2012
# Processing file: ./data/city-level2002.geojson
# Data loaded for year 2002
# Processing file: ./data/city-level2000.geojson
# Data loaded for year 2000
# Processing file: ./data/city-level2010.geojson
# Data loaded for year 2010
# Processing file: ./data/city-level1995.geojson
# Data loaded for year 1995
# Processing file: ./data/city-level2019.geojson
# Data loaded for year 2019
# Processing file: ./data/city-level2009.geojson
# Data loaded for year 2009
# Processing file: ./data/city-level2008.geojson
# Data loaded for year 2008
# Processing file: ./data/city-level2018.geojson
# Data loaded for year 2018
# Processing file: ./data/city-level2011.geojson
# Data loaded for year 2011
# Processing file: ./data/city-level2001.geojson
# Data loaded for year 2001
# Processing file: ./data/city-level1994.geojson
# Data loaded for year 1994
# Processing file: ./data/city-level1991.geojson
# Data loaded for year 1991
# Processing file: ./data/city-level2004.geojson
# Data loaded for year 2004
# Processing file: ./data/city-level2014.geojson
# Data loaded for year 2014
# Processing file: ./data/city-level1998.geojson
# Data loaded for year 1998
# Processing file: ./data/city-level1999.geojson
# Data loaded for year 1999
# Processing file: ./data/city-level1990.geojson
# Data loaded for year 1990
# Processing file: ./data/city-level2015.geojson
# Data loaded for year 2015
# Processing file: ./data/city-level2005.geojson
# Data loaded for year 2005
# Processing file: ./data/city-level2021.geojson
# Data loaded for year 2021
# Processing file: ./data/city-level2007.geojson
# Data loaded for year 2007
# Processing file: ./data/city-level2017.geojson
# Data loaded for year 2017
# Processing file: ./data/city-level1992.geojson
# Data loaded for year 1992
# Processing file: ./data/city-level2016.geojson
# Data loaded for year 2016
# Processing file: ./data/city-level2006.geojson
# Data loaded for year 2006
# Processing file: ./data/city-level1993.geojson
# Data loaded for year 1993
# Processing file: ./data/city-level2020.geojson
# Data loaded for year 2020

# %% [markdown]
# ##### 1. Print the first few rows of each GeoDataFrame to get a quick overview of the data:

# %%
# 1 Print the first few rows of each GeoDataFrame to get a quick overview of the data:
for year, data in data_by_year.items():
    print(f"Data for year {year}:")
    print(data.head())
    print("\n")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Data for year 1996:
#      省     省代码      市     市代码  \
# 0  北京市  110000  北京市辖区  110100
# 1  北京市  110000  北京市辖县  110200
# 2  天津市  120000  天津市辖区  120100
# 3  天津市  120000  天津市辖县  120200
# 4  河北省  130000   石家庄市  130100
#
#                                             geometry
# 0  MULTIPOLYGON (((115.95390 40.08780, 115.94240 ...
# 1  MULTIPOLYGON (((116.66140 41.03630, 116.64820 ...
# 2  MULTIPOLYGON (((118.05240 39.29560, 117.99580 ...
# 3  MULTIPOLYGON (((117.15690 38.74750, 117.17020 ...
# 4  MULTIPOLYGON (((113.84270 38.76480, 113.84310 ...
#
#
# Data for year 2003:
#      省     省代码      市     市代码  \
# 0  北京市  110000  北京市辖区  110100
# 1  北京市  110000  北京市辖县  110200
# 2  天津市  120000  天津市辖区  120100
# 3  天津市  120000  天津市辖县  120200
# 4  河北省  130000   石家庄市  130100
#
#                                             geometry
# 0  MULTIPOLYGON (((116.66140 41.03630, 116.64820 ...
# 1  MULTIPOLYGON (((116.45630 40.77910, 116.44340 ...
# 2  MULTIPOLYGON (((117.19980 39.83410, 117.17100 ...
# 3  MULTIPOLYGON (((117.15690 38.74750, 117.17020 ...
# 4  MULTIPOLYGON (((113.84270 38.76480, 113.84310 ...
#
#
# Data for year 2013:
#      省     省代码      市     市代码  \
# 0  北京市  110000  北京市辖区  110100
# 1  北京市  110000  北京市辖县  110200
# 2  天津市  120000  天津市辖区  120100
# 3  天津市  120000  天津市辖县  120200
# 4  河北省  130000   石家庄市  130100
#
#                                             geometry
# 0  MULTIPOLYGON (((116.66140 41.03630, 116.64820 ...
# 1  MULTIPOLYGON (((116.45630 40.77910, 116.44340 ...
# 2  MULTIPOLYGON (((117.19980 39.83410, 117.17100 ...
# 3  MULTIPOLYGON (((117.15690 38.74750, 117.17020 ...
# 4  MULTIPOLYGON (((113.84270 38.76480, 113.84310 ...
#
#
# Data for year 1997:
#      省     省代码      市     市代码  \
# 0  北京市  110000  北京市辖区  110100
# 1  北京市  110000  北京市辖县  110200
# 2  天津市  120000  天津市辖区  120100
# 3  天津市  120000  天津市辖县  120200
# 4  河北省  130000   石家庄市  130100
#
#                                             geometry
# 0  MULTIPOLYGON (((115.95390 40.08780, 115.94240 ...
# 1  MULTIPOLYGON (((116.50260 39.83210, 116.47140 ...
# 2  MULTIPOLYGON (((118.05900 39.28820, 118.03120 ...
# 3  MULTIPOLYGON (((117.15690 38.74750, 117.17020 ...
# 4  MULTIPOLYGON (((113.84270 38.76480, 113.84310 ...
#
#
# Data for year 2012:
#      省     省代码      市     市代码  \
# 0  北京市  110000  北京市辖区  110100
# 1  北京市  110000  北京市辖县  110200
# 2  天津市  120000  天津市辖区  120100
# 3  天津市  120000  天津市辖县  120200
# 4  河北省  130000   石家庄市  130100
#
#                                             geometry
# 0  MULTIPOLYGON (((116.66140 41.03630, 116.64820 ...
# 1  MULTIPOLYGON (((116.45630 40.77910, 116.44340 ...
# 2  MULTIPOLYGON (((117.19980 39.83410, 117.17100 ...
# 3  MULTIPOLYGON (((117.15690 38.74750, 117.17020 ...
# 4  MULTIPOLYGON (((113.84270 38.76480, 113.84310 ...
#
#
# Data for year 2002:
#      省     省代码      市     市代码  \
# 0  北京市  110000  北京市辖区  110100
# 1  北京市  110000  北京市辖县  110200
# 2  天津市  120000  天津市辖区  120100
# 3  天津市  120000  天津市辖县  120200
# 4  河北省  130000   石家庄市  130100
#
#                                             geometry
# 0  MULTIPOLYGON (((116.66140 41.03630, 116.64820 ...
# 1  MULTIPOLYGON (((116.45630 40.77910, 116.44340 ...
# 2  MULTIPOLYGON (((117.25200 39.84110, 117.41010 ...
# 3  MULTIPOLYGON (((117.15690 38.74750, 117.17020 ...
# 4  MULTIPOLYGON (((113.84270 38.76480, 113.84310 ...
#
#
# Data for year 2000:
#      省     省代码      市     市代码  \
# 0  北京市  110000  北京市辖区  110100
# 1  北京市  110000  北京市辖县  110200
# 2  天津市  120000  天津市辖区  120100
# 3  天津市  120000  天津市辖县  120200
# 4  河北省  130000   石家庄市  130100
#
#                                             geometry
# 0  MULTIPOLYGON (((116.43500 40.33810, 116.41100 ...
# 1  MULTIPOLYGON (((116.50260 39.83210, 116.47140 ...
# 2  MULTIPOLYGON (((116.93520 39.64200, 116.93440 ...
# 3  MULTIPOLYGON (((117.15690 38.74750, 117.17020 ...
# 4  MULTIPOLYGON (((113.84270 38.76480, 113.84310 ...
#
#
# Data for year 2010:
#      省     省代码      市     市代码  \
# 0  北京市  110000  北京市辖区  110100
# 1  北京市  110000  北京市辖县  110200
# 2  天津市  120000  天津市辖区  120100
# 3  天津市  120000  天津市辖县  120200
# 4  河北省  130000   石家庄市  130100
#
#                                             geometry
# 0  MULTIPOLYGON (((116.66140 41.03630, 116.64820 ...
# 1  MULTIPOLYGON (((116.45630 40.77910, 116.44340 ...
# 2  MULTIPOLYGON (((117.19980 39.83410, 117.17100 ...
# 3  MULTIPOLYGON (((117.15690 38.74750, 117.17020 ...
# 4  MULTIPOLYGON (((113.84270 38.76480, 113.84310 ...
#
#
# Data for year 1995:
#      省     省代码      市     市代码  \
# 0  北京市  110000  北京市辖区  110100
# 1  北京市  110000  北京市辖县  110200
# 2  天津市  120000  天津市辖区  120100
# 3  天津市  120000  天津市辖县  120200
# 4  河北省  130000   石家庄市  130100
#
#                                             geometry
# 0  MULTIPOLYGON (((115.95390 40.08780, 115.94240 ...
# 1  MULTIPOLYGON (((116.66140 41.03630, 116.64820 ...
# 2  MULTIPOLYGON (((118.05240 39.29560, 117.99580 ...
# 3  MULTIPOLYGON (((117.15690 38.74750, 117.17020 ...
# 4  MULTIPOLYGON (((113.84270 38.76480, 113.84310 ...
#
#
# Data for year 2019:
#         省代码    省       市代码     市   类型  \
# 0  110000.0  北京市  110000.0   北京市  直辖市
# 1  120000.0  天津市  120000.0   天津市  直辖市
# 2  130000.0  河北省  130100.0  石家庄市  地级市
# 3  130000.0  河北省  130200.0   唐山市  地级市
# 4  130000.0  河北省  130300.0  秦皇岛市  地级市
#
#                                             geometry
# 0  MULTIPOLYGON (((116.67527 41.04010, 116.67616 ...
# 1  MULTIPOLYGON (((117.44383 40.25101, 117.45611 ...
# 2  MULTIPOLYGON (((113.82422 38.75805, 113.83120 ...
# 3  MULTIPOLYGON (((118.85390 39.10692, 118.84934 ...
# 4  MULTIPOLYGON (((119.15209 40.61280, 119.15165 ...
#
#
# Data for year 2009:
#      省     省代码      市     市代码  \
# 0  北京市  110000  北京市辖县  110200
# 1  天津市  120000  天津市辖县  120200
# 2  河北省  130000   石家庄市  130100
# 3  河北省  130000   秦皇岛市  130300
# 4  河北省  130000    邯郸市  130400
#
#                                             geometry
# 0  MULTIPOLYGON (((116.45630 40.77910, 116.44340 ...
# 1  MULTIPOLYGON (((117.15690 38.74750, 117.17020 ...
# 2  MULTIPOLYGON (((113.84270 38.76480, 113.84310 ...
# 3  MULTIPOLYGON (((119.19060 40.60910, 119.15470 ...
# 4  MULTIPOLYGON (((114.08850 36.86150, 114.02080 ...
#
#
# Data for year 2008:
#      省     省代码      市     市代码  \
# 0  北京市  110000  北京市辖区  110100
# 1  北京市  110000  北京市辖县  110200
# 2  天津市  120000  天津市辖区  120100
# 3  天津市  120000  天津市辖县  120200
# 4  河北省  130000   石家庄市  130100
#
#                                             geometry
# 0  MULTIPOLYGON (((116.66140 41.03630, 116.64820 ...
# 1  MULTIPOLYGON (((116.45630 40.77910, 116.44340 ...
# 2  MULTIPOLYGON (((117.19980 39.83410, 117.17100 ...
# 3  MULTIPOLYGON (((117.15690 38.74750, 117.17020 ...
# 4  MULTIPOLYGON (((113.84270 38.76480, 113.84310 ...
#
#
# Data for year 2018:
#      省     省代码    市     市代码                                           geometry
# 0  安徽省  340000  安庆市  340800  MULTIPOLYGON (((116.58130 31.06830, 116.55260 ...
# 1  安徽省  340000  蚌埠市  340300  MULTIPOLYGON (((117.44320 33.38280, 117.41770 ...
# 2  安徽省  340000  亳州市  341600  MULTIPOLYGON (((116.37140 33.01590, 116.44350 ...
# 3  安徽省  340000  池州市  341700  MULTIPOLYGON (((118.12460 30.72040, 118.11840 ...
# 4  安徽省  340000  滁州市  341100  MULTIPOLYGON (((118.14660 33.17900, 118.07540 ...
#
#
# Data for year 2011:
#      省     省代码      市     市代码  \
# 0  北京市  110000  北京市辖区  110100
# 1  北京市  110000  北京市辖县  110200
# 2  天津市  120000  天津市辖区  120100
# 3  天津市  120000  天津市辖县  120200
# 4  河北省  130000   石家庄市  130100
#
#                                             geometry
# 0  MULTIPOLYGON (((116.66140 41.03630, 116.64820 ...
# 1  MULTIPOLYGON (((116.45630 40.77910, 116.44340 ...
# 2  MULTIPOLYGON (((117.19980 39.83410, 117.17100 ...
# 3  MULTIPOLYGON (((117.15690 38.74750, 117.17020 ...
# 4  MULTIPOLYGON (((113.84270 38.76480, 113.84310 ...
#
#
# Data for year 2001:
#      省     省代码      市     市代码  \
# 0  北京市  110000  北京市辖区  110100
# 1  北京市  110000  北京市辖县  110200
# 2  天津市  120000  天津市辖区  120100
# 3  天津市  120000  天津市辖县  120200
# 4  河北省  130000   石家庄市  130100
#
#                                             geometry
# 0  MULTIPOLYGON (((116.66140 41.03630, 116.64820 ...
# 1  MULTIPOLYGON (((116.45630 40.77910, 116.44340 ...
# 2  MULTIPOLYGON (((117.19980 39.83410, 117.17100 ...
# 3  MULTIPOLYGON (((117.15690 38.74750, 117.17020 ...
# 4  MULTIPOLYGON (((113.84270 38.76480, 113.84310 ...
#
#
# Data for year 1994:
#      省     省代码      市     市代码  \
# 0  北京市  110000  北京市辖区  110100
# 1  北京市  110000  北京市辖县  110200
# 2  天津市  120000  天津市辖区  120100
# 3  天津市  120000  天津市辖县  120200
# 4  河北省  130000   石家庄市  130100
#
#                                             geometry
# 0  MULTIPOLYGON (((115.95390 40.08780, 115.94240 ...
# 1  MULTIPOLYGON (((116.66140 41.03630, 116.64820 ...
# 2  MULTIPOLYGON (((118.05900 39.28820, 118.03120 ...
# 3  MULTIPOLYGON (((117.15690 38.74750, 117.17020 ...
# 4  MULTIPOLYGON (((115.24810 38.29980, 115.13410 ...
#
#
# Data for year 1991:
#      省     省代码      市     市代码  \
# 0  北京市  110000  北京市辖区  110100
# 1  北京市  110000  北京市辖县  110200
# 2  天津市  120000  天津市辖区  120100
# 3  天津市  120000  天津市辖县  120200
# 4  河北省  130000   石家庄市  130100
#
#                                             geometry
# 0  MULTIPOLYGON (((115.95390 40.08780, 115.94240 ...
# 1  MULTIPOLYGON (((116.66140 41.03630, 116.64820 ...
# 2  MULTIPOLYGON (((118.05240 39.29560, 117.99580 ...
# 3  MULTIPOLYGON (((117.15690 38.74750, 117.17020 ...
# 4  MULTIPOLYGON (((114.54240 38.31500, 114.50250 ...
#
#
# Data for year 2004:
#      省     省代码      市     市代码  \
# 0  北京市  110000  北京市辖县  110200
# 1  天津市  120000  天津市辖县  120200
# 2  河北省  130000   石家庄市  130100
# 3  河北省  130000   秦皇岛市  130300
# 4  河北省  130000    邯郸市  130400
#
#                                             geometry
# 0  MULTIPOLYGON (((116.45630 40.77910, 116.44340 ...
# 1  MULTIPOLYGON (((117.15690 38.74750, 117.17020 ...
# 2  MULTIPOLYGON (((113.84270 38.76480, 113.84310 ...
# 3  MULTIPOLYGON (((119.19060 40.60910, 119.15470 ...
# 4  MULTIPOLYGON (((114.08850 36.86150, 114.02080 ...
#
#
# Data for year 2014:
#      省     省代码      市     市代码  \
# 0  北京市  110000  北京市辖区  110100
# 1  北京市  110000  北京市辖县  110200
# 2  天津市  120000  天津市辖区  120100
# 3  天津市  120000  天津市辖县  120200
# 4  河北省  130000   石家庄市  130100
#
#                                             geometry
# 0  MULTIPOLYGON (((116.66140 41.03630, 116.64820 ...
# 1  MULTIPOLYGON (((116.45630 40.77910, 116.44340 ...
# 2  MULTIPOLYGON (((117.19980 39.83410, 117.17100 ...
# 3  MULTIPOLYGON (((117.15690 38.74750, 117.17020 ...
# 4  MULTIPOLYGON (((113.84270 38.76480, 113.84310 ...
#
#
# Data for year 1998:
#      省     省代码      市     市代码  \
# 0  北京市  110000  北京市辖区  110100
# 1  北京市  110000  北京市辖县  110200
# 2  天津市  120000  天津市辖区  120100
# 3  天津市  120000  天津市辖县  120200
# 4  河北省  130000   石家庄市  130100
#
#                                             geometry
# 0  MULTIPOLYGON (((116.87750 40.28950, 116.86580 ...
# 1  MULTIPOLYGON (((116.50260 39.83210, 116.47140 ...
# 2  MULTIPOLYGON (((118.05240 39.29560, 117.99580 ...
# 3  MULTIPOLYGON (((117.15690 38.74750, 117.17020 ...
# 4  MULTIPOLYGON (((113.84270 38.76480, 113.84310 ...
#
#
# Data for year 1999:
#      省     省代码      市     市代码  \
# 0  北京市  110000  北京市辖区  110100
# 1  北京市  110000  北京市辖县  110200
# 2  天津市  120000  天津市辖区  120100
# 3  天津市  120000  天津市辖县  120200
# 4  河北省  130000   石家庄市  130100
#
#                                             geometry
# 0  MULTIPOLYGON (((116.43500 40.33810, 116.41100 ...
# 1  MULTIPOLYGON (((116.50260 39.83210, 116.47140 ...
# 2  MULTIPOLYGON (((118.05240 39.29560, 117.99580 ...
# 3  MULTIPOLYGON (((117.15690 38.74750, 117.17020 ...
# 4  MULTIPOLYGON (((113.84270 38.76480, 113.84310 ...
#
#
# Data for year 1990:
#      省     省代码      市     市代码  \
# 0  北京市  110000  北京市辖区  110100
# 1  北京市  110000  北京市辖县  110200
# 2  天津市  120000  天津市辖区  120100
# 3  天津市  120000  天津市辖县  120200
# 4  河北省  130000   石家庄市  130100
#
#                                             geometry
# 0  MULTIPOLYGON (((115.95390 40.08780, 115.94240 ...
# 1  MULTIPOLYGON (((116.66140 41.03630, 116.64820 ...
# 2  MULTIPOLYGON (((118.05240 39.29560, 117.99580 ...
# 3  MULTIPOLYGON (((117.15690 38.74750, 117.17020 ...
# 4  MULTIPOLYGON (((114.54240 38.31500, 114.50250 ...
#
#
# Data for year 2015:
#      省     省代码    市     市代码                                           geometry
# 0  安徽省  340000  安庆市  340800  MULTIPOLYGON (((117.12210 31.16890, 117.10270 ...
# 1  安徽省  340000  蚌埠市  340300  MULTIPOLYGON (((117.50930 33.35020, 117.48520 ...
# 2  安徽省  340000  亳州市  341600  MULTIPOLYGON (((116.37140 33.01590, 116.44350 ...
# 3  安徽省  340000  池州市  341700  MULTIPOLYGON (((118.11800 30.68160, 118.12650 ...
# 4  安徽省  340000  滁州市  341100  MULTIPOLYGON (((118.19600 33.20040, 118.16390 ...
#
#
# Data for year 2005:
#      省     省代码      市     市代码  \
# 0  北京市  110000  北京市辖区  110100
# 1  北京市  110000  北京市辖县  110200
# 2  天津市  120000  天津市辖区  120100
# 3  天津市  120000  天津市辖县  120200
# 4  河北省  130000   石家庄市  130100
#
#                                             geometry
# 0  MULTIPOLYGON (((116.66140 41.03630, 116.64820 ...
# 1  MULTIPOLYGON (((116.45630 40.77910, 116.44340 ...
# 2  MULTIPOLYGON (((117.19980 39.83410, 117.17100 ...
# 3  MULTIPOLYGON (((117.15690 38.74750, 117.17020 ...
# 4  MULTIPOLYGON (((113.84270 38.76480, 113.84310 ...
#
#
# Data for year 2021:
#      省       省代码 省类型    市       市代码  市类型  \
# 0  安徽省  340000.0   省  安庆市  340800.0  地级市
# 1  安徽省  340000.0   省  蚌埠市  340300.0  地级市
# 2  安徽省  340000.0   省  亳州市  341600.0  地级市
# 3  安徽省  340000.0   省  池州市  341700.0  地级市
# 4  安徽省  340000.0   省  滁州市  341100.0  地级市
#
#                                             geometry
# 0  MULTIPOLYGON (((117.04743 31.23795, 117.04959 ...
# 1  MULTIPOLYGON (((117.24217 33.50295, 117.24328 ...
# 2  MULTIPOLYGON (((115.75364 34.06824, 115.75751 ...
# 3  MULTIPOLYGON (((117.97799 30.82233, 117.97173 ...
# 4  MULTIPOLYGON (((118.21608 33.14179, 118.21502 ...
#
#
# Data for year 2007:
#      省     省代码      市     市代码  \
# 0  北京市  110000  北京市辖区  110100
# 1  北京市  110000  北京市辖县  110200
# 2  天津市  120000  天津市辖区  120100
# 3  天津市  120000  天津市辖县  120100
# 4  河北省  130000   石家庄市  130100
#
#                                             geometry
# 0  MULTIPOLYGON (((116.66140 41.03630, 116.64820 ...
# 1  MULTIPOLYGON (((116.45630 40.77910, 116.44340 ...
# 2  MULTIPOLYGON (((117.19980 39.83410, 117.17100 ...
# 3  MULTIPOLYGON (((117.15690 38.74750, 117.17020 ...
# 4  MULTIPOLYGON (((113.84270 38.76480, 113.84310 ...
#
#
# Data for year 2017:
#      省     省代码    市     市代码                                           geometry
# 0  安徽省  340000  安庆市  340800  MULTIPOLYGON (((117.08800 31.22550, 117.04070 ...
# 1  安徽省  340000  蚌埠市  340300  MULTIPOLYGON (((117.46310 33.36850, 117.44320 ...
# 2  安徽省  340000  亳州市  341600  MULTIPOLYGON (((116.37140 33.01590, 116.44350 ...
# 3  安徽省  340000  池州市  341700  MULTIPOLYGON (((118.12730 30.71170, 118.12460 ...
# 4  安徽省  340000  滁州市  341100  MULTIPOLYGON (((118.15420 33.20550, 118.14660 ...
#
#
# Data for year 1992:
#      省     省代码      市     市代码  \
# 0  北京市  110000  北京市辖区  110100
# 1  北京市  110000  北京市辖县  110200
# 2  天津市  120000  天津市辖区  120100
# 3  天津市  120000  天津市辖县  120200
# 4  河北省  130000   石家庄市  130100
#
#                                             geometry
# 0  MULTIPOLYGON (((115.95390 40.08780, 115.94240 ...
# 1  MULTIPOLYGON (((116.66140 41.03630, 116.64820 ...
# 2  MULTIPOLYGON (((118.05240 39.29560, 117.99580 ...
# 3  MULTIPOLYGON (((117.15690 38.74750, 117.17020 ...
# 4  MULTIPOLYGON (((114.54240 38.31500, 114.50250 ...
#
#
# Data for year 2016:
#      省     省代码    市     市代码                                           geometry
# 0  安徽省  340000  安庆市  340800  POLYGON ((117.10270 31.20850, 117.08800 31.225...
# 1  安徽省  340000  蚌埠市  340300  POLYGON ((117.48520 33.35780, 117.46310 33.368...
# 2  安徽省  340000  亳州市  341600  POLYGON ((116.37140 33.01590, 116.44350 32.990...
# 3  安徽省  340000  池州市  341700  POLYGON ((118.12650 30.70230, 118.12730 30.711...
# 4  安徽省  340000  滁州市  341100  POLYGON ((118.16390 33.21290, 118.15420 33.205...
#
#
# Data for year 2006:
#      省     省代码      市     市代码  \
# 0  北京市  110000  北京市辖区  110100
# 1  北京市  110000  北京市辖县  110200
# 2  天津市  120000  天津市辖区  120100
# 3  天津市  120000  天津市辖县  120200
# 4  河北省  130000   石家庄市  130100
#
#                                             geometry
# 0  MULTIPOLYGON (((116.66140 41.03630, 116.64820 ...
# 1  MULTIPOLYGON (((116.45630 40.77910, 116.44340 ...
# 2  MULTIPOLYGON (((117.19980 39.83410, 117.17100 ...
# 3  MULTIPOLYGON (((117.15690 38.74750, 117.17020 ...
# 4  MULTIPOLYGON (((113.84270 38.76480, 113.84310 ...
#
#
# Data for year 1993:
#      省     省代码        市     市代码  \
# 0  北京市  110000    北京市辖区  110100
# 1  北京市  110000    北京市辖县  110200
# 2  天津市  120000    天津市辖区  120100
# 3  天津市  120000    天津市辖县  120200
# 4  河北省  130000  省直辖行政单位  130100
#
#                                             geometry
# 0  MULTIPOLYGON (((115.95390 40.08780, 115.94240 ...
# 1  MULTIPOLYGON (((116.66140 41.03630, 116.64820 ...
# 2  MULTIPOLYGON (((118.05900 39.28820, 118.03120 ...
# 3  MULTIPOLYGON (((117.15690 38.74750, 117.17020 ...
# 4  MULTIPOLYGON (((114.93260 38.34840, 114.92870 ...
#
#
# Data for year 2020:
#      省       省代码 省类型    市       市代码  市类型  \
# 0  安徽省  340000.0   省  安庆市  340800.0  地级市
# 1  安徽省  340000.0   省  蚌埠市  340300.0  地级市
# 2  安徽省  340000.0   省  亳州市  341600.0  地级市
# 3  安徽省  340000.0   省  池州市  341700.0  地级市
# 4  安徽省  340000.0   省  滁州市  341100.0  地级市
#
#                                             geometry
# 0  MULTIPOLYGON (((117.04743 31.23795, 117.04959 ...
# 1  MULTIPOLYGON (((117.24217 33.50295, 117.24328 ...
# 2  MULTIPOLYGON (((115.75364 34.06824, 115.75751 ...
# 3  MULTIPOLYGON (((117.97799 30.82233, 117.97173 ...
# 4  MULTIPOLYGON (((118.21608 33.14179, 118.21502 ...

# %% [markdown]
# ##### 2. List all columns in the GeoDataFrames:

# %%
# 2 List all columns in the GeoDataFrames:
for year, data in data_by_year.items():
    print(f"Columns for year {year}:")
    print(data.columns)
    print("\n")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Columns for year 1996:
# Index(['省', '省代码', '市', '市代码', 'geometry'], dtype='object')
#
#
# Columns for year 2003:
# Index(['省', '省代码', '市', '市代码', 'geometry'], dtype='object')
#
#
# Columns for year 2013:
# Index(['省', '省代码', '市', '市代码', 'geometry'], dtype='object')
#
#
# Columns for year 1997:
# Index(['省', '省代码', '市', '市代码', 'geometry'], dtype='object')
#
#
# Columns for year 2012:
# Index(['省', '省代码', '市', '市代码', 'geometry'], dtype='object')
#
#
# Columns for year 2002:
# Index(['省', '省代码', '市', '市代码', 'geometry'], dtype='object')
#
#
# Columns for year 2000:
# Index(['省', '省代码', '市', '市代码', 'geometry'], dtype='object')
#
#
# Columns for year 2010:
# Index(['省', '省代码', '市', '市代码', 'geometry'], dtype='object')
#
#
# Columns for year 1995:
# Index(['省', '省代码', '市', '市代码', 'geometry'], dtype='object')
#
#
# Columns for year 2019:
# Index(['省代码', '省', '市代码', '市', '类型', 'geometry'], dtype='object')
#
#
# Columns for year 2009:
# Index(['省', '省代码', '市', '市代码', 'geometry'], dtype='object')
#
#
# Columns for year 2008:
# Index(['省', '省代码', '市', '市代码', 'geometry'], dtype='object')
#
#
# Columns for year 2018:
# Index(['省', '省代码', '市', '市代码', 'geometry'], dtype='object')
#
#
# Columns for year 2011:
# Index(['省', '省代码', '市', '市代码', 'geometry'], dtype='object')
#
#
# Columns for year 2001:
# Index(['省', '省代码', '市', '市代码', 'geometry'], dtype='object')
#
#
# Columns for year 1994:
# Index(['省', '省代码', '市', '市代码', 'geometry'], dtype='object')
#
#
# Columns for year 1991:
# Index(['省', '省代码', '市', '市代码', 'geometry'], dtype='object')
#
#
# Columns for year 2004:
# Index(['省', '省代码', '市', '市代码', 'geometry'], dtype='object')
#
#
# Columns for year 2014:
# Index(['省', '省代码', '市', '市代码', 'geometry'], dtype='object')
#
#
# Columns for year 1998:
# Index(['省', '省代码', '市', '市代码', 'geometry'], dtype='object')
#
#
# Columns for year 1999:
# Index(['省', '省代码', '市', '市代码', 'geometry'], dtype='object')
#
#
# Columns for year 1990:
# Index(['省', '省代码', '市', '市代码', 'geometry'], dtype='object')
#
#
# Columns for year 2015:
# Index(['省', '省代码', '市', '市代码', 'geometry'], dtype='object')
#
#
# Columns for year 2005:
# Index(['省', '省代码', '市', '市代码', 'geometry'], dtype='object')
#
#
# Columns for year 2021:
# Index(['省', '省代码', '省类型', '市', '市代码', '市类型', 'geometry'], dtype='object')
#
#
# Columns for year 2007:
# Index(['省', '省代码', '市', '市代码', 'geometry'], dtype='object')
#
#
# Columns for year 2017:
# Index(['省', '省代码', '市', '市代码', 'geometry'], dtype='object')
#
#
# Columns for year 1992:
# Index(['省', '省代码', '市', '市代码', 'geometry'], dtype='object')
#
#
# Columns for year 2016:
# Index(['省', '省代码', '市', '市代码', 'geometry'], dtype='object')
#
#
# Columns for year 2006:
# Index(['省', '省代码', '市', '市代码', 'geometry'], dtype='object')
#
#
# Columns for year 1993:
# Index(['省', '省代码', '市', '市代码', 'geometry'], dtype='object')
#
#
# Columns for year 2020:
# Index(['省', '省代码', '省类型', '市', '市代码', '市类型', 'geometry'], dtype='object')

# %% [markdown]
# ##### 3. List all columns in the GeoDataFrames for year 2020 and 2021:

# %%
# 3 List all columns in the GeoDataFrames for year 2020 and 2021:
for year, data in data_by_year.items():
    if year in [2020, 2021]:
        print(f"Columns for year {year}:")
        print(data.columns)
        print("\n")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Columns for year 2021:
# Index(['province', 'province_code', 'province_level', 'city', 'city_code',
#        'city_level', 'geometry'],
#       dtype='object')
#
#
# Columns for year 2020:
# Index(['province', 'province_code', 'province_level', 'city', 'city_code',
#        'city_level', 'geometry'],
#       dtype='object')

# %% [markdown]
# ##### 4. Rename columns to English

# %%
# 4 Rename the columns in the GeoDataFrames for year 1990-2019 省 to province, 市 to city, 省代码 to province_code, 市代码 to city_code.
for year, data in data_by_year.items():
    if year in range(1990, 2020):
        data.rename(columns={'省': 'province', '市': 'city', '省代码': 'province_code', '市代码': 'city_code'}, inplace=True)
        print(f"Columns for year {year}:")
        print(data.columns)
        print("\n")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Columns for year 1996:
# Index(['province', 'province_code', 'city', 'city_code', 'geometry'], dtype='object')
#
#
# Columns for year 2003:
# Index(['province', 'province_code', 'city', 'city_code', 'geometry'], dtype='object')
#
#
# Columns for year 2013:
# Index(['province', 'province_code', 'city', 'city_code', 'geometry'], dtype='object')
#
#
# Columns for year 1997:
# Index(['province', 'province_code', 'city', 'city_code', 'geometry'], dtype='object')
#
#
# Columns for year 2012:
# Index(['province', 'province_code', 'city', 'city_code', 'geometry'], dtype='object')
#
#
# Columns for year 2002:
# Index(['province', 'province_code', 'city', 'city_code', 'geometry'], dtype='object')
#
#
# Columns for year 2000:
# Index(['province', 'province_code', 'city', 'city_code', 'geometry'], dtype='object')
#
#
# Columns for year 2010:
# Index(['province', 'province_code', 'city', 'city_code', 'geometry'], dtype='object')
#
#
# Columns for year 1995:
# Index(['province', 'province_code', 'city', 'city_code', 'geometry'], dtype='object')
#
#
# Columns for year 2019:
# Index(['province_code', 'province', 'city_code', 'city', '类型', 'geometry'], dtype='object')
#
#
# Columns for year 2009:
# Index(['province', 'province_code', 'city', 'city_code', 'geometry'], dtype='object')
#
#
# Columns for year 2008:
# Index(['province', 'province_code', 'city', 'city_code', 'geometry'], dtype='object')
#
#
# Columns for year 2018:
# Index(['province', 'province_code', 'city', 'city_code', 'geometry'], dtype='object')
#
#
# Columns for year 2011:
# Index(['province', 'province_code', 'city', 'city_code', 'geometry'], dtype='object')
#
#
# Columns for year 2001:
# Index(['province', 'province_code', 'city', 'city_code', 'geometry'], dtype='object')
#
#
# Columns for year 1994:
# Index(['province', 'province_code', 'city', 'city_code', 'geometry'], dtype='object')
#
#
# Columns for year 1991:
# Index(['province', 'province_code', 'city', 'city_code', 'geometry'], dtype='object')
#
#
# Columns for year 2004:
# Index(['province', 'province_code', 'city', 'city_code', 'geometry'], dtype='object')
#
#
# Columns for year 2014:
# Index(['province', 'province_code', 'city', 'city_code', 'geometry'], dtype='object')
#
#
# Columns for year 1998:
# Index(['province', 'province_code', 'city', 'city_code', 'geometry'], dtype='object')
#
#
# Columns for year 1999:
# Index(['province', 'province_code', 'city', 'city_code', 'geometry'], dtype='object')
#
#
# Columns for year 1990:
# Index(['province', 'province_code', 'city', 'city_code', 'geometry'], dtype='object')
#
#
# Columns for year 2015:
# Index(['province', 'province_code', 'city', 'city_code', 'geometry'], dtype='object')
#
#
# Columns for year 2005:
# Index(['province', 'province_code', 'city', 'city_code', 'geometry'], dtype='object')
#
#
# Columns for year 2007:
# Index(['province', 'province_code', 'city', 'city_code', 'geometry'], dtype='object')
#
#
# Columns for year 2017:
# Index(['province', 'province_code', 'city', 'city_code', 'geometry'], dtype='object')
#
#
# Columns for year 1992:
# Index(['province', 'province_code', 'city', 'city_code', 'geometry'], dtype='object')
#
#
# Columns for year 2016:
# Index(['province', 'province_code', 'city', 'city_code', 'geometry'], dtype='object')
#
#
# Columns for year 2006:
# Index(['province', 'province_code', 'city', 'city_code', 'geometry'], dtype='object')
#
#
# Columns for year 1993:
# Index(['province', 'province_code', 'city', 'city_code', 'geometry'], dtype='object')

# %%
# 5 Rename the columns in the GeoDataFrames for year 2020 and 2021 since they have different column names.
for year, data in data_by_year.items():
    if year in [2020, 2021]:
        data.rename(columns={'省': 'province', '省类型': 'province_level', 
                             '市': 'city', '市类型': 'city_level', '省代码': 'province_code', 
                             '市代码': 'city_code'}, inplace=True)
        print(f"Columns for year {year}:")
        print(data.columns)
        print("\n")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Columns for year 2021:
# Index(['province', 'province_code', 'province_level', 'city', 'city_code',
#        'city_level', 'geometry'],
#       dtype='object')
#
#
# Columns for year 2020:
# Index(['province', 'province_code', 'province_level', 'city', 'city_code',
#        'city_level', 'geometry'],
#       dtype='object')

# %% [markdown]
# ##### 5. Generate sepreated GEOJSON files by province + year

# %%
# Define the years to include
years = list(range(1990, 2022))

# Get the unique provinces
provinces = set(province for gdf in data_by_year.values() for province in gdf['province'].unique())

# Loop through all provinces and years and generate the GeoJSON files
for province in provinces:
    for year in years:
        # Check if the year exists in the data
        if year in data_by_year:
            # Filter the data for the current province and year
            gdf = data_by_year[year][data_by_year[year]['province'] == province]
            
            # Add a new column 'year' to the GeoDataFrame
            gdf['year'] = year
            
            # Define the file path for the GeoJSON file
            file_path = os.path.join(data_directory, f'{province}{year}.geojson')
            
            # Export the GeoDataFrame to a GeoJSON file
            gdf.to_file(file_path, driver='GeoJSON')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
import glob

# Define the province
province = '河北省'

# Get a list of all the GeoJSON files for the province
file_paths = glob.glob(os.path.join(data_directory, f'{province}*.geojson'))

# Initialize an empty list to store the GeoDataFrames
gdfs = []

# Loop through all the file paths and read each file
for file_path in file_paths:
    gdf = gpd.read_file(file_path)
    gdfs.append(gdf)

# Concatenate all the GeoDataFrames into a single GeoDataFrame
gdf_hebei = pd.concat(gdfs, ignore_index=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# 1 Visualize the data using geemap and visually inspect their boundaries.
# Create a Map instance
Map = geemap.Map()

# Define the years to include and their corresponding colors
years = [1990, 1991, 1992, 1994]
colors = ['red', 'green', 'blue', 'black']

# Loop through the selected years and add each GeoDataFrame as a layer
for year, color in zip(years, colors):
    # Filter the GeoDataFrame for the current year
    gdf = gdf_hebei[gdf_hebei['year'] == year]
    
    style = {
    "stroke": True,
    "color": color,  # change the color for each year
    "weight": 2,
    "opacity": 1,
    "fill": True,
    "fillColor": color,  # change the fill color for each year
    "fillOpacity": 0.1,
    }

    hover_style = {"fillOpacity": 0.6}

    Map.add_gdf(gdf, layer_name=f'City boundaries in {year}', style=style, hover_style=hover_style)

Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[0, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=SearchDataGUI(childr…

# %% [markdown]
# #### Step 2: Identifying City and City_Code Changes and Boundary Changes

# %%
# 1 Visualize the data using geemap and visually inspect their boundaries.
# Create a Map instance
Map = geemap.Map()

# Define the years to include and their corresponding colors
years = [1990, 1991, 1992, 1993]
colors = ['red', 'green', 'blue', 'black']

# Loop through the selected years and add each GeoDataFrame as a layer
for year, color in zip(years, colors):
    gdf = data_by_year[year]
    
    style = {
    "stroke": True,
    "color": color,  # change the color for each year
    "weight": 2,
    "opacity": 1,
    "fill": True,
    "fillColor": color,  # change the fill color for each year
    "fillOpacity": 0.1,
    }

    hover_style = {"fillOpacity": 0.6}

    Map.add_gdf(gdf, layer_name=f'City boundaries in {year}', style=style, hover_style=hover_style)

Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[0, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=SearchDataGUI(childr…

# %%
# Function to compare geometries between all years and 2021
def compare_geometries_to_2021():
    changes = []
    gdf2021 = data_by_year[2021]
    
    # Create a spatial index for 2021 for efficient querying
    spatial_index_2021 = gdf2021.sindex
    
    for year, gdf in data_by_year.items():
        if year == 2021:
            continue

        for _, row in gdf.iterrows():
            possible_matches_index = list(spatial_index_2021.intersection(row['geometry'].bounds))
            possible_matches = gdf2021.iloc[possible_matches_index]
            precise_matches = possible_matches[possible_matches.geometry.apply(lambda geom: geom.equals(row['geometry']))]
            
            for _, match in precise_matches.iterrows():
                # Check for name or code changes
                if row['city'] != match['city'] or row['city_code'] != match['city_code']:
                    changes.append({
                        'year': year,
                        'original_name': row['city'],
                        'new_name': match['city'],
                        'original_code': row['city_code'],
                        'new_code': match['city_code']
                    })
    
    # Convert changes to a DataFrame for easier tracking
    changes_df = pd.DataFrame(changes)
    
    # Print the DataFrame to check its contents
    print(changes_df)
    
    return changes_df

# Example usage
changes_to_2021 = compare_geometries_to_2021()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Empty DataFrame
# Columns: []
# Index: []
